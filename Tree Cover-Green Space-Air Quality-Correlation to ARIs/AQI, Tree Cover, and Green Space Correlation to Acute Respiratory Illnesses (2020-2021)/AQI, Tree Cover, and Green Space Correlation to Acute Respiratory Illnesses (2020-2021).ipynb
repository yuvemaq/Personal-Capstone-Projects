# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Tree-Cover,-Green-Space,-and-Air-Quality-Correlation-to-Acute-Respiratory-Illnesses-in-Cleveland,-Los-Angeles,-New-York,-and-Tampa-(2020-2021-Data)-(EDA)" data-toc-modified-id="Tree-Cover,-Green-Space,-and-Air-Quality-Correlation-to-Acute-Respiratory-Illnesses-in-Cleveland,-Los-Angeles,-New-York,-and-Tampa-(2020-2021-Data)-(EDA)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Tree Cover, Green Space, and Air Quality Correlation to Acute Respiratory Illnesses in Cleveland, Los Angeles, New York, and Tampa (2020-2021 Data) (EDA)</a></span><ul class="toc-item"><li><span><a href="#Outer-merge-the-two-dataframes" data-toc-modified-id="Outer-merge-the-two-dataframes-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Outer merge the two dataframes</a></span></li><li><span><a href="#Plotting-yearly-average-PM2.5-AQI-levels-for-Cleveland,-Los-Angeles,-New-York,-and-Tampa-2020-2021" data-toc-modified-id="Plotting-yearly-average-PM2.5-AQI-levels-for-Cleveland,-Los-Angeles,-New-York,-and-Tampa-2020-2021-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Plotting yearly average PM2.5 AQI levels for Cleveland, Los Angeles, New York, and Tampa 2020-2021</a></span></li><li><span><a href="#Two-cities-comparison" data-toc-modified-id="Two-cities-comparison-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Two-cities comparison</a></span></li><li><span><a href="#Cumulative-Moving-Average" data-toc-modified-id="Cumulative-Moving-Average-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Cumulative Moving Average</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Tree Cover, Green Space, and Air Quality Correlation to Acute Respiratory Illnesses in Cleveland, Los Angeles, New York, and Tampa (2020-2021 Data) (EDA)

# %% [markdown]
# 1. Data Wrangling

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import pickle
import seaborn as sns
# %matplotlib inline
import string
import collections

from pandas.plotting import register_matplotlib_converters
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.feature_extraction import text
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# I. Cleveland-Elyria OH

# %%
df_cle = pd.read_csv(r'D:\AQIdata\air_cle.csv')
df_cle.head()
# Out:
#          Date  PM2.5 AQI Value  Main Pollutant            Site Name  \
# 0  01/01/2020               44             NaN  Cleveland Near Road
# 1  01/02/2020               25             NaN  Cleveland Near Road
# 2  01/03/2020               57             NaN  Cleveland Near Road
# 3  01/04/2020               48             NaN  Cleveland Near Road
# 4  01/05/2020               28             NaN  Cleveland Near Road
#
#        Site ID Source
# 0  39-035-0073    AQS
# 1  39-035-0073    AQS
# 2  39-035-0073    AQS
# 3  39-035-0073    AQS
# 4  39-035-0073    AQS

# %%
df_cle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             731 non-null    object
#  1   PM2.5 AQI Value  731 non-null    int64
#  2   Main Pollutant   0 non-null      float64
#  3   Site Name        731 non-null    object
#  4   Site ID          731 non-null    object
#  5   Source           731 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 34.4+ KB

# %%
df_cle.shape
# Out:
# (731, 6)

# %%
df_cle.isnull().sum()
# Out:
# Date                 0
# PM2.5 AQI Value      0
# Main Pollutant     731
# Site Name            0
# Site ID              0
# Source               0
# dtype: int64

# %%
df_cle = df_cle.drop(columns='Main Pollutant')
df_cle.isnull().sum()
# Out:
# Date               0
# PM2.5 AQI Value    0
# Site Name          0
# Site ID            0
# Source             0
# dtype: int64

# %%
df_cle['Date']= pd.to_datetime(df_cle['Date'])

# %%
# calculate the yearly average PM2.5 AQI 
df_cle['AQI_Value'] = df_cle.mean(axis=1)

# drop columns containing monthly values
df_aqi_cle = df_cle[['AQI_Value']]

# visualize the first 5 columns
df_aqi_cle.head()
# Out:
#    AQI_Value
# 0       44.0
# 1       25.0
# 2       57.0
# 3       48.0
# 4       28.0

# %% [markdown]
# II. Los Angeles CA

# %%
df_la = pd.read_csv(r'D:\AQIdata\air_la.csv')
df_la.head()
# Out:
#          Date  PM2.5 AQI Value  Main Pollutant  \
# 0  01/01/2020              102             NaN
# 1  01/02/2020               72             NaN
# 2  01/03/2020               87             NaN
# 3  01/04/2020              104             NaN
# 4  01/05/2020              103             NaN
#
#                         Site Name      Site ID Source
# 0  Long Beach-Route 710 Near Road  06-037-4008    AQS
# 1                         Compton  06-037-1302    AQS
# 2  Long Beach-Route 710 Near Road  06-037-4008    AQS
# 3                         Compton  06-037-1302    AQS
# 4                         Compton  06-037-1302    AQS

# %%
df_la.isnull().sum()
# Out:
# Date                 0
# PM2.5 AQI Value      0
# Main Pollutant     731
# Site Name            0
# Site ID              0
# Source               0
# dtype: int64

# %%
df_la = df_la.drop(columns='Main Pollutant')

# %%
df_la['Date']= pd.to_datetime(df_la['Date'])

# %%
# calculate the yearly average PM2.5 AQI 
df_la['AQI_Value'] = df_la.mean(axis=1)

# drop columns containing monthly values
df_aqi_la = df_la[['AQI_Value']]

# visualize the first 5 columns
df_aqi_la.head()
# Out:
#    AQI_Value
# 0      102.0
# 1       72.0
# 2       87.0
# 3      104.0
# 4      103.0

# %% [markdown]
# III. New York-Newark-Jersey City, NY-NJ-PA

# %%
df_ny = pd.read_csv(r'D:\AQIdata\air_ny.csv')
df_ny.head()
# Out:
#          Date  PM2.5 AQI Value  Main Pollutant                Site Name  \
# 0  01/01/2020               36             NaN  Intermediate School 143
# 1  01/02/2020               56             NaN  Intermediate School 143
# 2  01/03/2020               68             NaN       Fort Lee Near Road
# 3  01/04/2020               63             NaN       Fort Lee Near Road
# 4  01/05/2020               37             NaN                     CCNY
#
#        Site ID Source
# 0  36-061-0115    AQS
# 1  36-061-0115    AQS
# 2  34-003-0010    AQS
# 3  34-003-0010    AQS
# 4  36-061-0135    AQS

# %%
df_ny = df_ny.drop(columns='Main Pollutant')

# %%
df_ny['Date']= pd.to_datetime(df_ny['Date'])

# %%
# calculate the yearly average PM2.5 AQI 
df_ny['AQI_Value'] = df_ny.mean(axis=1)

# drop columns containing monthly values
df_aqi_ny = df_ny[['AQI_Value']]

# visualize the first 5 columns
df_aqi_ny.head()
# Out:
#    AQI_Value
# 0       36.0
# 1       56.0
# 2       68.0
# 3       63.0
# 4       37.0

# %% [markdown]
# IV. Tampa-St. Petersburg-Clearwater, FL

# %%
df_ta = pd.read_csv(r'D:\AQIdata\air_tp.csv')
df_ta.head()
# Out:
#          Date  PM2.5 AQI Value  Main Pollutant  \
# 0  01/01/2020              108             NaN
# 1  01/02/2020               40             NaN
# 2  01/03/2020               38             NaN
# 3  01/04/2020               36             NaN
# 4  01/05/2020               24             NaN
#
#                            Site Name      Site ID Source
# 0                             SYDNEY  12-057-3002    AQS
# 1                             SYDNEY  12-057-3002    AQS
# 2        USMC Reserve Center (Gandy)  12-057-1065    AQS
# 3  John Chesnut Sr. Park - East Lake  12-103-5002    AQS
# 4  John Chesnut Sr. Park - East Lake  12-103-5002    AQS

# %%
df_ta = df_ta.drop(columns='Main Pollutant')

# %%
df_ta['Date']= pd.to_datetime(df_ta['Date'])

# %%
# calculate the yearly average PM2.5 AQI 
df_ta['AQI_Value'] = df_ta.mean(axis=1)

# drop columns containing monthly values
df_aqi_ta = df_ta[['AQI_Value']]

# visualize the first 5 columns
df_aqi_ta.head()
# Out:
#    AQI_Value
# 0      108.0
# 1       40.0
# 2       38.0
# 3       36.0
# 4       24.0

# %% [markdown]
# ## Outer merge the two dataframes

# %%
outer_merge0 = pd.merge(df_cle, df_la, how="outer", on=["AQI_Value", "PM2.5 AQI Value"] )

# %%
outer_merge0.head()
# Out:
#       Date_x  PM2.5 AQI Value          Site Name_x    Site ID_x Source_x  \
# 0 2020-01-01               44  Cleveland Near Road  39-035-0073      AQS
# 1 2020-01-01               44  Cleveland Near Road  39-035-0073      AQS
# 2 2020-01-01               44  Cleveland Near Road  39-035-0073      AQS
# 3 2020-01-01               44  Cleveland Near Road  39-035-0073      AQS
# 4 2020-01-01               44  Cleveland Near Road  39-035-0073      AQS
#
#    AQI_Value     Date_y                     Site Name_y    Site ID_y Source_y
# 0       44.0 2020-05-14              Long Beach (South)  06-037-4004      AQS
# 1       44.0 2021-03-08                  Pico Rivera #2  06-037-1602      AQS
# 2       44.0 2021-03-20          North Hollywood (NOHO)  06-037-4010      AQS
# 3       44.0 2021-03-26  Long Beach-Route 710 Near Road  06-037-4008      AQS
# 4       44.0 2021-06-08   Los Angeles-North Main Street  06-037-1103      AQS

# %%
outer_merge1 = pd.merge(df_ny, df_ta, how="outer", on=["AQI_Value", "PM2.5 AQI Value"] )

# %%
outer_merge1.head()
# Out:
#       Date_x  PM2.5 AQI Value              Site Name_x    Site ID_x Source_x  \
# 0 2020-01-01               36  Intermediate School 143  36-061-0115      AQS
# 1 2020-01-01               36  Intermediate School 143  36-061-0115      AQS
# 2 2020-01-01               36  Intermediate School 143  36-061-0115      AQS
# 3 2020-01-01               36  Intermediate School 143  36-061-0115      AQS
# 4 2020-01-01               36  Intermediate School 143  36-061-0115      AQS
#
#    AQI_Value     Date_y                        Site Name_y    Site ID_y  \
# 0       36.0 2020-01-04  John Chesnut Sr. Park - East Lake  12-103-5002
# 1       36.0 2020-01-09        USMC Reserve Center (Gandy)  12-057-1065
# 2       36.0 2020-01-19           Munro Street (Near-Road)  12-057-0113
# 3       36.0 2020-01-24        USMC Reserve Center (Gandy)  12-057-1065
# 4       36.0 2020-02-29                             SYDNEY  12-057-3002
#
#   Source_y
# 0      AQS
# 1      AQS
# 2      AQS
# 3      AQS
# 4      AQS

# %% [markdown]
# ## Plotting yearly average PM2.5 AQI levels for Cleveland, Los Angeles, New York, and Tampa 2020-2021

# %%
df_aqi_cle.rename({'AQI_Value': 'AQI Value CLE'}, axis=1, inplace=True)
df_aqi_la.rename({'AQI_Value': 'AQI Value LA'}, axis=1, inplace=True)
df_aqi_ny.rename({'AQI_Value': 'AQI Value NY-NJ'}, axis=1, inplace=True)
df_aqi_ta.rename({'AQI_Value': 'AQI Value TPA'}, axis=1, inplace=True)

# %%
# Merge using inner merge
from functools import reduce
import pandas as pd

df = [df_aqi_cle,df_aqi_la,df_aqi_ny,df_aqi_ta]
nan_value=0

merged = reduce(lambda df_left,df_right: pd.merge(df_left, df_right, 
                                              left_index=True, right_index=True, 
                                              how='inner'), df).fillna(nan_value)

# %%
merged.head()
# Out:
#    AQI Value CLE  AQI Value LA  AQI Value NY-NJ  AQI Value TPA
# 0           44.0         102.0             36.0          108.0
# 1           25.0          72.0             56.0           40.0
# 2           57.0          87.0             68.0           38.0
# 3           48.0         104.0             63.0           36.0
# 4           28.0         103.0             37.0           24.0

# %%
# Plot
plt.style.use('seaborn')
plt.figure(figsize=(25,14))

# line plot - the yearly average AQI in Cleveland-Elyria, OH and Los Angeles, CA
ax0 = merged['AQI Value CLE'].plot(color='orange', linewidth=1.5, grid=True, label='Cleveland')
ax1 = merged['AQI Value LA'].plot(color='blue', linewidth=1.5, grid=True, label='Los Angeles')
ax2 = merged['AQI Value NY-NJ'].plot(color='red', linewidth=1.5, grid=True, label='New York')
ax3 = merged['AQI Value TPA'].plot(color='green', linewidth=1.5, grid=True, label='Tampa')
ax0.legend(fontsize=16, loc=1)
ax1.legend(fontsize=16, loc=1)
ax2.legend(fontsize=16, loc=2)
ax3.legend(fontsize=16, loc=2)


# title and labels
plt.title('Yearly average PM2.5 AQI in Cleveland-Elyria, Los Angeles-Long-Beach-Anaheim, New York-Newark-Jersey City, and Tampa from 2020-2021', fontsize=20)
plt.xlabel('Year', fontsize=20)
plt.ylabel('AQI Value', fontsize=20)
plt.ylim(20,160)
plt.show()

# %% [markdown]
# ## Two-cities comparison

# %%
aqi_df0 = df_aqi_ny.join(df_aqi_la, lsuffix='_left', rsuffix='_right')
aqi_df0.head()
# Out:
#    AQI Value NY-NJ  AQI Value LA
# 0             36.0         102.0
# 1             56.0          72.0
# 2             68.0          87.0
# 3             63.0         104.0
# 4             37.0         103.0

# %%
# Plotting NY-NJ and LA PM2.5 AQI levels
plt.style.use('seaborn')
plt.figure(figsize=(16,10))

# line plot - the yearly average AQI in New York and Los Angeles
ax0 = aqi_df0['AQI Value NY-NJ'].plot(color='red', linewidth=2, grid=True, label='New York-New Jersey')
ax1 = aqi_df0['AQI Value LA'].plot(color='blue', linewidth=2, grid=True, label='Los Angeles', secondary_y=True)
ax0.legend(fontsize=12, loc=1)
ax1.legend(fontsize=12, loc=2)


# title and labels
plt.title('Yearly average AQI levels of all pollutants in New York-Newark-Jersey City and Los Angeles from 2020-2021', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('AQI Value', fontsize=16)
plt.show()

# %%
aqi_df1 = df_aqi_cle.join(df_aqi_ny, lsuffix='_left', rsuffix='_right')
aqi_df1.head()
# Out:
#    AQI Value CLE  AQI Value NY-NJ
# 0           44.0             36.0
# 1           25.0             56.0
# 2           57.0             68.0
# 3           48.0             63.0
# 4           28.0             37.0

# %%
# Plotting CLE and NY-NJ PM2.5 AQI levels
plt.style.use('seaborn')
plt.figure(figsize=(16,10))

# line plot - the yearly average AQI in Cleveland and New York-New Jersey
ax0 = aqi_df1['AQI Value CLE'].plot(color='orange', linewidth=2, grid=True, label='Cleveland')
ax1 = aqi_df1['AQI Value NY-NJ'].plot(color='red', linewidth=2, grid=True, label='New York-New Jersey', secondary_y=True)
ax0.legend(fontsize=12, loc=1)
ax1.legend(fontsize=12, loc=2)


# title and labels
plt.title('Yearly average AQI levels of all pollutants in Cleveland and New York-Newark-Jersey City from 2020-2021', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('AQI Value', fontsize=16)
plt.show()

# %%
aqi_df2 = df_aqi_ta.join(df_aqi_cle, lsuffix='_left', rsuffix='_right')
aqi_df2.head()
# Out:
#    AQI Value TPA  AQI Value CLE
# 0          108.0           44.0
# 1           40.0           25.0
# 2           38.0           57.0
# 3           36.0           48.0
# 4           24.0           28.0

# %%
# Plotting Tampa and CLE PM2.5 AQI levels
plt.style.use('seaborn')
plt.figure(figsize=(16,10))

# line plot - the yearly average AQI in Tampa, FL and Cleveland
ax0 = aqi_df2['AQI Value TPA'].plot(color='green', linewidth=2, grid=True, label='Tampa')
ax1 = aqi_df2['AQI Value CLE'].plot(color='orange', linewidth=2, grid=True, label='Cleveland', secondary_y=True)
ax0.legend(fontsize=12, loc=1)
ax1.legend(fontsize=12, loc=2)


# title and labels
plt.title('Yearly average AQI levels of all pollutants in Tampa, FL and Cleveland from 2020-2021', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('AQI Value', fontsize=16)
plt.show()

# %%
aqi_df3 = df_aqi_la.join(df_aqi_cle, lsuffix='_left', rsuffix='_right')
aqi_df3.head()
# Out:
#    AQI Value LA  AQI Value CLE
# 0         102.0           44.0
# 1          72.0           25.0
# 2          87.0           57.0
# 3         104.0           48.0
# 4         103.0           28.0

# %%
# Plotting LA and CLE PM2.5 AQI levels
plt.style.use('seaborn')
plt.figure(figsize=(16,10))

# line plot - the yearly average AQI in LA and CLE
ax0 = aqi_df3['AQI Value LA'].plot(color='blue', linewidth=2, grid=True, label='Los Angeles')
ax1 = aqi_df3['AQI Value CLE'].plot(color='orange', linewidth=2, grid=True, label='Cleveland', secondary_y=True)
ax0.legend(fontsize=12, loc=1)
ax1.legend(fontsize=12, loc=2)


# title and labels
plt.title('Yearly average AQI levels of all pollutants in Los Angeles and Cleveland from 2020-2021', fontsize=20)
plt.xlabel('Year', fontsize=16)
plt.ylabel('AQI Value', fontsize=16)
plt.show()

# %% [markdown]
# ## Cumulative Moving Average

# %%
# cumulative moving averages for each city
df_cle['CMA'] = df_cle['PM2.5 AQI Value'].expanding().mean()
df_la['CMA'] = df_la['PM2.5 AQI Value'].expanding().mean()
df_ny['CMA'] = df_ny['PM2.5 AQI Value'].expanding().mean()
df_ta['CMA'] = df_ta['PM2.5 AQI Value'].expanding().mean()

# %%
# Plot
# Colors for line plot
colors = ['purple', 'orange']

# line plot - the yearly average AQI levels
ax0 = df_cle[['AQI_Value', 'CMA']].plot(color=colors, linewidth=3, figsize=(12,6))
ax1 = df_la[['AQI_Value', 'CMA']].plot(color=colors, linewidth=3, figsize=(12,6))
ax2 = df_ny[['AQI_Value', 'CMA']].plot(color=colors, linewidth=3, figsize=(12,6))
ax3 = df_ta[['AQI_Value', 'CMA']].plot(color=colors, linewidth=3, figsize=(12,6))
ax0.legend(fontsize=12, loc=1)
ax1.legend(fontsize=12, loc=2)
ax2.legend(fontsize=12, loc=2)
ax3.legend(fontsize=12, loc=2)

# modify ticks size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(labels =['Average Ozone AQI Value', 'CMA'], fontsize=14)

# title and labels
ax0.set_title('Cumulative moving average of AQI levels in Cleveland', fontsize=20)
ax0.set_xlabel('Year', fontsize=16)
ax0.set_ylabel('AQI Value', fontsize=16)
ax1.set_title('Cumulative moving average of AQI levels in Los Angeles', fontsize=20)
ax1.set_xlabel('Year', fontsize=16)
ax1.set_ylabel('AQI Value', fontsize=16)
ax2.set_title('Cumulative moving average of AQI levels in New York', fontsize=20)
ax2.set_xlabel('Year', fontsize=16)
ax2.set_ylabel('AQI Value', fontsize=16)
ax3.set_title('Cumulative moving average of AQI levels in Tampa', fontsize=20)
ax3.set_xlabel('Year', fontsize=16)
ax3.set_ylabel('AQI Value', fontsize=16)
# Out:
# Text(0, 0.5, 'AQI Value')
